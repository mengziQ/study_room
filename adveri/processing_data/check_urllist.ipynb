# %%
# %config IPCompleter.greedy=True

# %%
import pandas as pd

# %%
df = pd.read_table('./data/url_list_by_bing_201805.tsv')

# %%
df
# Out:
#                                                      url cate
# 0                   https://zuuonline.com/archives/82254  たばこ
# 1      https://www.e-healthnet.mhlw.go.jp/information...  たばこ
# 2      https://www.e-healthnet.mhlw.go.jp/information...  たばこ
# 3      https://www.e-healthnet.mhlw.go.jp/information...  たばこ
# 4      https://www.e-healthnet.mhlw.go.jp/information...  たばこ
# 5                  http://www.denshitabako.net/shop.html  たばこ
# 6                    http://www.dentaba-shop.com/14.html  たばこ
# 7                    http://www.dentaba-shop.com/15.html  たばこ
# 8      https://ja.wikipedia.org/wiki/%E3%82%8F%E3%81%...  たばこ
# 9      http://www.diet100sen.com/entry/2014/02/11/212546  たばこ
# 10     http://www.diet100sen.com/entry/2014/02/19/000525  たばこ
# 11     http://www.dims.ne.jp/timelyresearch/2010/100112/  たばこ
# 12     http://josei-bigaku.jp/tabakonokemuriakatyan5950/  たばこ
# 13     https://ja.m.wikipedia.org/wiki/%E3%82%8F%E3%8...  たばこ
# ...

# %%
# where句とlike句
df_adult = df[df['cate'].str.contains('アダルト')]
df_nega = df[df['cate'].str.contains('ネガティブ')]
df_al = df[df['cate'].str.contains('アルコール')]
df_tab = df[df['cate'].str.contains('たばこ')]
df_dep = df[df['cate'].str.contains('百貨店')]
df_sp = df[df['cate'].str.contains('スーパー')]

# %%
print('アダルト: ', len(df_adult.index))
print('ネガティブ: ', len(df_nega.index))
print('アルコール: ', len(df_al.index))
print('たばこ: ', len(df_tab.index))
print('百貨店: ', len(df_dep.index))
print('スーパー: ', len(df_sp.index))
# Out:
# アダルト:  5116
# ネガティブ:  3338
# アルコール:  2616
# たばこ:  1592
# 百貨店:  1855
# スーパー:  2184
