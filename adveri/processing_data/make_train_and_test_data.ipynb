# %%
# %config IPCompleter.greedy=True

# %%
import pandas as pd

# %%
#df = pd.read_table('/home/moeko-asano/adveli_work/data/target/corpus_all_20180517.tsv')
df_test = pd.read_table('./data/corpus_all_20180530_test.tsv', header=None)
print(len(df_test.index))
# Out:
# 14850

# %%
df_test[0].value_counts()
#df
# Out:
# アパレル         550
# 宝くじ・遊戯       550
# IT・Web       550
# 医療・福祉        550
# ネガティブ        550
# 保険           550
# 電気機器         550
# 自動車・バイク      550
# 食品・飲料/日用品    550
# ポイントサイト      550
# アダルト         550
# エンタメ         550
# 出産・育児        550
# アルコール類       550
# 教育・学習塾       550
# 不動産          550
# 通信・キャリア      550
# 化粧品・スキンケア    550
# 2chまとめ       550
# 人材紹介・派遣      550
# 外食           550
# 金融           550
# 旅行           550
# 結婚・出会い・婚活    550
# たばこ          550
# スーパー・百貨店     550
# 政治           550
# Name: 0, dtype: int64

# %%
# ターゲットカテゴリ用
df_2ch = df[df['target']=='2chまとめ'].sample(frac=1.0)
df_spo = df[df['target']=='スポーツ'].sample(frac=1.0)
df_marr = df[df['target']=='結婚・出会い・婚活'].sample(frac=1.0)
df_talent = df[df['target']=='芸能人'].sample(frac=1.0)
df_poli = df[df['target']=='政治'].sample(frac=1.0)
df_rest = df[df['target']=='外食'].sample(frac=1.0)
df_beau = df[df['target']=='化粧品・スキンケア'].sample(frac=1.0)
df_tv = df[df['target']=='テレビ'].sample(frac=1.0)
df_com = df[df['target']=='お笑い'].sample(frac=1.0)
df_mov = df[df['target']=='映画'].sample(frac=1.0)
df_edu = df[df['target']=='教育・学習塾'].sample(frac=1.0)
df_adult = df[df['target']=='アダルト'].sample(frac=1.0)
df_nega = df[df['target']=='ネガティブ'].sample(frac=1.0)
df_blog = df[df['target']=='ブログ'].sample(frac=1.0)
df_out = df[df['target']=='アウトドア'].sample(frac=1.0)
df_appa = df[df['target']=='アパレル'].sample(frac=1.0)
df_ani = df[df['target']=='アニメ'].sample(frac=1.0)
df_eve = df[df['target']=='イベント'].sample(frac=1.0)
df_fin = df[df['target']=='金融'].sample(frac=1.0)
df_music = df[df['target']=='音楽'].sample(frac=1.0)
df_con = df[df['target']=='生活用品'].sample(frac=1.0)
df_tran = df[df['target']=='交通手段'].sample(frac=1.0)
df_auto = df[df['target']=='自動車'].sample(frac=1.0)
df_gam = df[df['target']=='ギャンブル'].sample(frac=1.0)
df_alc = df[df['target']=='アルコール'].sample(frac=1.0)
df_game = df[df['target']=='ゲーム'].sample(frac=1.0)
df_super = df[df['target']=='スーパー'].sample(frac=1.0)

df_sns =  df[df['target']=='SNS'].sample(frac=1.0)
df_heal =  df[df['target']=='健康'].sample(frac=1.0)
df_twitter =  df[df['target']=='twitter'].sample(frac=1.0)
df_hr = df[df['target']=='人材'].sample(frac=1.0)
df_dep = df[df['target']=='百貨店'].sample(frac=1.0)
df_tech =  df[df['target']=='テクノロジー'].sample(frac=1.0)
df_trip =  df[df['target']=='旅行'].sample(frac=1.0)
df_point =  df[df['target']=='ポイントサイト'].sample(frac=1.0)
df_cam = df[df['target']=='カメラ'].sample(frac=1.0)
df_taba = df[df['target']=='たばこ'].sample(frac=1.0)
df_ins =  df[df['target']=='保険'].sample(frac=1.0)
df_re =  df[df['target']=='不動産'].sample(frac=1.0)
df_and =  df[df['target']=='Android'].sample(frac=1.0)
df_pc = df[df['target']=='PC周辺'].sample(frac=1.0)
df_ip = df[df['target']=='iPhone'].sample(frac=1.0)


#df_sns =  df[df['target']=='SNS']
#df_heal =  df[df['target']=='健康']
#df_twitter =  df[df['target']=='twitter']
#df_hr = df[df['target']=='人材']
#df_dep = df[df['target']=='百貨店']
#df_tech =  df[df['target']=='テクノロジー']
#df_trip =  df[df['target']=='旅行']
#df_point =  df[df['target']=='ポイントサイト']
#df_cam = df[df['target']=='カメラ']
#df_taba = df[df['target']=='たばこ']
#df_ins =  df[df['target']=='保険']
#df_re =  df[df['target']=='不動産']
#df_and =  df[df['target']=='Android']
#df_pc = df[df['target']=='PC周辺']
#df_ip = df[df['target']=='iPhone']

df_child =  df[df['target']=='出産・育児']
df_book =  df[df['target']=='本']
df_commu =  df[df['target']=='通信']
df_gad = df[df['target']=='ガジェット']
df_drama = df[df['target']=='海外ドラマ']
df_medi =  df[df['target']=='医療']
df_gossip = df[df['target']=='ゴシップ']
df_bike = df[df['target']=='バイク']

            
df_2ch = df_2ch.head(2000)
df_spo = df_spo.head(2000)
df_marr = df_marr.head(2000)
df_talent = df_talent.head(2000)
df_poli = df_poli.head(2000)
df_rest = df_rest.head(2000)
df_beau = df_beau.head(2000)
df_tv = df_tv.head(2000)
df_com = df_com.head(2000)
df_mov = df_mov.head(2000)
df_edu = df_edu.head(2000)
df_adult = df_adult.head(2000)
df_nega = df_nega.head(2000)
df_blog = df_blog.head(2000)
df_out = df_out.head(2000)
df_appa = df_appa.head(2000)
df_ani = df_ani.head(2000)
df_eve = df_eve.head(2000)
df_fin = df_fin.head(2000)
df_music = df_music.head(2000)
df_con = df_con.head(2000)
df_tran = df_tran.head(2000)
df_auto = df_auto.head(2000)
df_gam = df_gam.head(2000)
df_alc = df_alc.head(2000)
df_game = df_game.head(2000)
df_super = df_super.head(2000)

df_sns =  df_sns.head(2000)
df_heal =  df_heal.head(2000)
df_twitter =  df_twitter.head(2000)
df_hr = df_hr.head(2000)
df_dep = df_dep.head(2000)
df_tech =  df_tech.head(2000)
df_trip =  df_trip.head(2000)
df_point =  df_point.head(2000)
df_cam = df_cam.head(2000)
df_taba = df_taba.head(2000)
df_ins =  df_ins.head(2000)
df_re =  df_re.head(2000)
df_and =  df_and.head(2000)
df_pc = df_pc.head(2000)
df_ip = df_ip.head(2000)

# %%
# アドベリメニュー用
df_adult = df_test[df_test[0]=='アダルト'].sample(frac=1.0)
df_car = df_test[df_test[0]=='自動車・バイク'].sample(frac=1.0)
df_ele = df_test[df_test[0]=='電気機器'].sample(frac=1.0)
df_commu = df_test[df_test[0]=='通信・キャリア'].sample(frac=1.0)
df_it = df_test[df_test[0]=='IT・Web'].sample(frac=1.0)
df_enter = df_test[df_test[0]=='エンタメ'].sample(frac=1.0)
df_tra = df_test[df_test[0]=='旅行'].sample(frac=1.0)
df_apa = df_test[df_test[0]=='アパレル'].sample(frac=1.0)
df_make = df_test[df_test[0]=='化粧品・スキンケア'].sample(frac=1.0)
df_taba = df_test[df_test[0]=='たばこ'].sample(frac=1.0)
df_al = df_test[df_test[0]=='アルコール類'].sample(frac=1.0)
df_play = df_test[df_test[0]=='宝くじ・遊戯'].sample(frac=1.0)
df_rea = df_test[df_test[0]=='不動産'].sample(frac=1.0)
df_hr = df_test[df_test[0]=='人材紹介・派遣'].sample(frac=1.0)
df_fin = df_test[df_test[0]=='金融'].sample(frac=1.0)
df_en = df_test[df_test[0]=='保険'].sample(frac=1.0)
df_marr = df_test[df_test[0]=='結婚・出会い・婚活'].sample(frac=1.0)
df_baby = df_test[df_test[0]=='出産・育児'].sample(frac=1.0)
df_edu = df_test[df_test[0]=='教育・学習塾'].sample(frac=1.0)
df_doc = df_test[df_test[0]=='医療・福祉'].sample(frac=1.0)
df_res = df_test[df_test[0]=='外食'].sample(frac=1.0)
df_poli = df_test[df_test[0]=='政治'].sample(frac=1.0)
df_food = df_test[df_test[0]=='食品・飲料/日用品'].sample(frac=1.0)
df_super = df_test[df_test[0]=='スーパー・百貨店'].sample(frac=1.0)
df_2ch = df_test[df_test[0]=='2chまとめ'].sample(frac=1.0)
df_po = df_test[df_test[0]=='ポイントサイト'].sample(frac=1.0)
df_nega = df_test[df_test[0]=='ネガティブ'].sample(frac=1.0)

df_adult = df_adult.head(550)
df_car = df_car.head(550)
df_ele = df_ele.head(550)
df_commu = df_commu.head(550)
df_it = df_it.head(550)
df_enter = df_enter.head(550)
df_tra = df_tra.head(550)
df_apa = df_apa.head(550)
df_make = df_make.head(550)
df_taba = df_taba.head(550)
df_al = df_al.head(550)
df_play = df_play.head(550)
df_rea = df_rea.head(550)
df_hr = df_hr.head(550)
df_fin = df_fin.head(550)
df_en = df_en.head(550)
df_marr = df_marr.head(550)
df_baby = df_baby.head(550)
df_edu = df_edu.head(550)
df_doc = df_doc.head(550)
df_res = df_res.head(550)
df_poli = df_poli.head(550)
df_food = df_food.head(550)
df_super = df_super.head(550)
df_2ch = df_2ch.head(550)
df_po = df_po.head(550)
df_nega = df_nega.head(550)

# %%
# 各タグのデータ数を揃えたところで結合
# ターゲット用
df_revised = pd.concat([df_2ch, df_spo, df_marr, df_talent, df_poli, df_rest, df_beau, df_tv, df_com, df_mov, df_edu, df_adult, df_nega, \
                        df_blog, df_out, df_appa, df_ani, df_eve, df_fin, df_music, df_con, df_tran, df_auto, df_gam, df_alc, df_game, \
                        df_super, df_sns, df_heal, df_twitter, df_hr, df_dep, df_tech, df_trip, df_point, df_cam, df_taba, df_ins, df_re, df_and, \
                        df_pc, df_ip, df_child, df_book, df_commu, df_gad, df_drama, df_medi, df_gossip, df_bike])
print(len(df_revised.index))
# Out:
# 97596

# %%
# 各タグのデータ数を揃えたところで結合
# アドベリメニュー用
df_revised = pd.concat([df_adult, df_car, df_ele, df_commu, df_it, df_enter, df_tra, df_apa,  
df_make, df_taba, df_al, df_play, df_rea, df_hr, df_fin, df_en, df_marr, df_baby, df_edu, \
df_doc, df_res, df_poli, df_food, df_super, df_2ch, df_po, df_nega])
print(len(df_revised.index))
# Out:
# 14850

# %%
df_sample = df.sample(frac=1.0)
df_train = df_sample[:309229]
df_test = df_sample[309230:]
print(len(df_train.index))
print(len(df_test.index))
# Out:
# 309229
# 132527

# %%
df_train
# Out:
#                 0                                                  1
# 91116        エンタメ  　俳優の中尾明慶が６日、日本テレビ系「スッキリ」で、妻で女優の仲里依紗との“格差”を訴えた。...
# 86003        エンタメ  ★サンスポコムに掲載　ハッシュタグをつけよう！　オフィシャルハッシュタグ「＃ＭＡＳＡストーリ...
# 301886       エンタメ  　4月10日発売の「週刊女性」が息子や娘たちの入学式に出席した芸能人夫婦のコーデを報じた。そ...
# 114429  結婚・出会い・婚活         【セックス／モデルプレス】今彼氏やセックスする相手がいるあなた、どのくらいのペ...
# 387522     2chまとめ  ノム速｜2ちゃんねるまとめブログ　　スポンサードリンクおすすめスポンサードリンクお知らせ記事...
# 32059         不動産  【土地活用コラム】第6回三世代が幸せに暮らすための「代々設計」を学ぶ。～【基本編】～｜フ...
# 349105     2chまとめ  「2016年03月」日時の記事2016/03/311:風吹けば名無し＠＼(^o^)／2016...
# 193584       エンタメ  番組の進行役でありながら、華の存在でもある女子アナウンサーたち。アナウンスの技術は当然ながら...
# 393491     2chまとめ  にゅーれすを設置しました。新着ニュース[sponsoredlink][sponsoredli...
# 126251       アパレル  こんにちは(*^_^*) 本日より伊勢丹新宿で行われる伊勢丹メイクアップパーティが始まりまし...
# 188551       エンタメ        © デイリースポーツ/神戸新聞社  ダウンタウン・松本人志  ダウンタウンの松本...
# 37352       医療・福祉  朗報！毎日の野菜不足を手軽に効率的に補う方法が密かに話題朗報！毎日の野菜不足を手軽に効率的に...
# 195016       エンタメ  また、4月13日よりスタートの痛快クイズ番組「チコちゃんに叱られる」と、4月2日から始まる永...
# ...

# %%
df_test
# Out:
#                 0                                                  1
# 347683     2chまとめ  おはようございますネタ切れどころか毎日ネタがない我が家ネタは作るもの？そんな我が家に小ネタが...
# 199476  結婚・出会い・婚活  　こんにちは。サラリーマンメンタリストのtatsuです。　前回はバラエティ番組に出た出川哲朗...
# 62096        アダルト  キス・ディープキスでうつる病気　＜キスと性病＞|アポロくん、性病検査を語る普通の軽いキスくら...
# 335062     2chまとめ  こちらコメント募集中の記事になります【ガンダム*】*←この印が付いてるものが募集中の記事です...
# 387104     2chまとめ                                              Gone.
# 391391     2chまとめ  女性向けのおすすめクレカここは女性向けのオススメのクレジットカードを紹介しているサイトです。...
# 391380     2chまとめ                                       声優。まとめ。速報。画像
# 29948     自動車・バイク  2014.12.11松山英樹の専属キャディ進藤大典氏のブログvol.157アンダー１３位。出...
# 139639     宝くじ・遊技  バイオマス原料を配合した家庭ごみの有料指定袋（左）。従来の袋（右）と異なり、温室効果ガス排出...
# 154525         旅行  ■時紀行　美しい渦潮とは――。　兵庫県の淡路島と徳島県を隔てる鳴門海峡の代名詞を、科学的に解...
# 383770     2chまとめ               Justamoment...RayID:419e09b4b22da566
# 399878     2chまとめ                                          スポンサードリンク
# 285492         政治  参院決算委で質問を聞く安倍首相と麻生財務相9時　参院決算委員会。午前の参院決算委員会で最初に...
# ...

# %%
# tsv出力(index消す)
#df_train.to_csv('./data/corpus_all_20180530_train.tsv', sep='\t', index=False)
df_test.to_csv('./data/corpus_all_20180530_test_2.tsv', sep='\t', index=False)

# %%
# ２０００件に揃えたver(学習・テストに分けていない)
df_revised.to_csv('./data/corpus_all_20180530_test.tsv', sep='\t', index=False)
